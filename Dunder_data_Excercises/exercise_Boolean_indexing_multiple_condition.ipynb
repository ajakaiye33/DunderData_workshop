# %%
#import necessary packages
import pandas as pd

# %%
#read data into pandas
movie = pd.read_csv('data/movie.csv', index_col='title')
movie.head()
# Out:
#                                               year  color content_rating  \
# title
# Avatar                                      2009.0  Color          PG-13
# Pirates of the Caribbean: At World's End    2007.0  Color          PG-13
# Spectre                                     2015.0  Color          PG-13
# The Dark Knight Rises                       2012.0  Color          PG-13
# Star Wars: Episode VII - The Force Awakens     NaN    NaN            NaN
#
#                                             duration      director_name  \
# title
# Avatar                                         178.0      James Cameron
# Pirates of the Caribbean: At World's End       169.0     Gore Verbinski
# Spectre                                        148.0         Sam Mendes
# The Dark Knight Rises                          164.0  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens       NaN        Doug Walker
#
#                                             director_fb           actor1  \
# ...

# %%
#select all movies from the 1970
filt1 = movie['year'] >= 1970 
filt2 = movie['year'] < 1980
filt = filt1 & filt2
movie[filt].head()
# Out:
#                                  year            color content_rating  \
# title
# All That Jazz                  1979.0            Color              R
# Superman                       1978.0            Color             PG
# Solaris                        1972.0  Black and White             PG
# Mean Streets                   1973.0            Color              R
# Star Trek: The Motion Picture  1979.0            Color             PG
#
#                                duration     director_name  director_fb  \
# title
# All That Jazz                     123.0         Bob Fosse        189.0
# Superman                          188.0    Richard Donner        503.0
# Solaris                           115.0  Andrei Tarkovsky          0.0
# Mean Streets                      112.0   Martin Scorsese      17000.0
# Star Trek: The Motion Picture     143.0       Robert Wise        338.0
#
#                                          actor1  actor1_fb  \
# title
# ...

# %%
#select movies from the 1970s that had IMDB scores greater than 8
filt3 = movie['imdb_score'] > 8
filty = filt & filt3
movie[filty].head()
# Out:
#                                       year            color content_rating  \
# title
# Solaris                             1972.0  Black and White             PG
# Apocalypse Now                      1979.0            Color              R
# The Deer Hunter                     1978.0            Color              R
# The Godfather: Part II              1974.0            Color              R
# Star Wars: Episode IV - A New Hope  1977.0            Color             PG
#
#                                     duration         director_name  \
# title
# Solaris                                115.0      Andrei Tarkovsky
# Apocalypse Now                         289.0  Francis Ford Coppola
# The Deer Hunter                        183.0        Michael Cimino
# The Godfather: Part II                 220.0  Francis Ford Coppola
# Star Wars: Episode IV - A New Hope     125.0          George Lucas
#
#                                     director_fb            actor1  actor1_fb  \
# title
# ...

# %%
#select movies that were rated either R, PG-13, or PG
rating_lst = ['R', 'PG-13', 'PG']
filt = movie['content_rating'].isin(rating_lst)
movie[filt].head()
# Out:
#                                             year  color content_rating  \
# title
# Avatar                                    2009.0  Color          PG-13
# Pirates of the Caribbean: At World's End  2007.0  Color          PG-13
# Spectre                                   2015.0  Color          PG-13
# The Dark Knight Rises                     2012.0  Color          PG-13
# John Carter                               2012.0  Color          PG-13
#
#                                           duration      director_name  \
# title
# Avatar                                       178.0      James Cameron
# Pirates of the Caribbean: At World's End     169.0     Gore Verbinski
# Spectre                                      148.0         Sam Mendes
# The Dark Knight Rises                        164.0  Christopher Nolan
# John Carter                                  132.0     Andrew Stanton
#
#                                           director_fb           actor1  \
# title
# ...

# %%
#select movies that are either rated Pg-13 or were made after 2010
filt1 = movie['content_rating'] == 'PG-13'
filt2 = movie['year'] > 2010
filt = filt1 | filt2
movie[filt].head()
movie[~filt]
# Out:
#                                                       year            color  \
# title
# Star Wars: Episode VII - The Force Awakens             NaN              NaN
# Tangled                                             2010.0            Color
# Harry Potter and the Half-Blood Prince              2009.0            Color
# The Chronicles of Narnia: Prince Caspian            2008.0            Color
# Alice in Wonderland                                 2010.0            Color
# TRON: Legacy                                        2010.0            Color
# Toy Story 3                                         2010.0            Color
# WALL·E                                              2008.0            Color
# A Christmas Carol                                   2009.0            Color
# The Chronicles of Narnia: The Lion, the Witch a...  2005.0            Color
# Up                                                  2009.0            Color
# ...

# %% [markdown]
# movies that are not either PG-13 rated or made after 2010

# %%
# find all the movies that have at least one of the three actors with more than 10,000 facebook likes
filt1 = movie['actor1_fb'] > 10000
filt2 = movie['actor2_fb'] > 10000
filt3 = movie['actor3_fb'] > 10000
filt = filt1 | filt2 | filt3
movie[filt].head(3)
# Out:
#                                             year  color content_rating  \
# title
# Pirates of the Caribbean: At World's End  2007.0  Color          PG-13
# Spectre                                   2015.0  Color          PG-13
# The Dark Knight Rises                     2012.0  Color          PG-13
#
#                                           duration      director_name  \
# title
# Pirates of the Caribbean: At World's End     169.0     Gore Verbinski
# Spectre                                      148.0         Sam Mendes
# The Dark Knight Rises                        164.0  Christopher Nolan
#
#                                           director_fb           actor1  \
# title
# Pirates of the Caribbean: At World's End        563.0      Johnny Depp
# Spectre                                           0.0  Christoph Waltz
# The Dark Knight Rises                         22000.0        Tom Hardy
#
#                                           actor1_fb          actor2  \
# title
# ...
